# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# style settings 
plt.rcParams['font.family'] = 'DejaVu Sans'

# %%
# load the dataset
data = pd.read_csv('psychology_sales_dataset.csv')

# %%
pd.set_option('display.max_columns', None) 
print("Sample data:")
data.sample(3)
# Out:
# Sample data:
#         customer_id  age  gender    city education_level occupation  \
# 301703       401704   53  Female  Tabriz        Bachelor    Analyst
# 231814       331815   18    Male   Karaj        Bachelor    Analyst
# 531682       631683   25  Female  Tehran          Master    Manager
#
#         stress_level  anxiety_score  self_esteem  impulsiveness  \
# 301703          5.48           6.04         4.96           1.00
# 231814          8.16            NaN         3.90           9.23
# 531682          7.87           5.65         2.57           2.96
#
#         optimism_score  life_satisfaction  social_media_dependency  \
# 301703            5.78               6.70                    10.00
# 231814            4.70               3.28                     7.50
# 531682            8.13               5.96                     1.93
#
#         weekly_site_visits  total_orders  average_order_value  total_spent  \
# ...

# %%
from classes.data_info_display import DataInfoDisplay
from classes.missing_values_analyzer import MissingValuesAnalyzer
print("✅ Classes successfully reloaded")
# display data information using the DataInfoDisplay class
data_display = DataInfoDisplay(data=data)   
data_display.display()
# analyze missing values using the MissingValuesAnalyzer class
missing_values_analyzer = MissingValuesAnalyzer(data=data)
if hasattr(missing_values_analyzer, "display"):
    missing_values_analyzer.display()
elif hasattr(missing_values_analyzer, "analyze"):
    missing_values_analyzer.analyze()
elif hasattr(missing_values_analyzer, "run"):
    missing_values_analyzer.run()
else:
    print("MissingValuesAnalyzer has no display/analyze/run method. Available methods:",
          [m for m in dir(missing_values_analyzer) if not m.startswith("_")])
# Out:
# ✅ Classes successfully reloaded
#                                Data Info
# ╭─────────────────────────┬──────────┬─────────┬─────────┬────────────╮
# │ Column                  │ Non-Null │ Unique  │  Dtype  │ Sample     │
# ├─────────────────────────┼──────────┼─────────┼─────────┼────────────┤
# │ customer_id             │ 550,000  │ 550,000 │  int64  │ 100001     │
# │ age                     │ 550,000  │   58    │  int64  │ 38         │
# │ gender                  │ 550,000  │    2    │ object  │ Male       │
# │ city                    │ 550,000  │    6    │ object  │ Karaj      │
# │ education_level         │ 550,000  │    4    │ object  │ PhD        │
# │ occupation              │ 533,500  │    6    │ object  │ Freelancer │
# │ stress_level            │ 550,000  │   901   │ float64 │ 5.2        │
# │ anxiety_score           │ 517,104  │  1,373  │ float64 │ 5.88       │
# │ self_esteem             │ 528,000  │   901   │ float64 │ 2.29       │
# ...
